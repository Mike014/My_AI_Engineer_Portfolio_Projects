# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Building Advanced Transformers**
#
# **Estimated time needed:  30 minutes**
#
# In this lab, you will implement and experiment with advanced Transformer models using Keras.
#
# **Learning objectives:**
#
# By the end of this lab, you will:
#
# - Implement advanced Transformer models using Keras.
#
# - Apply Transformers to real-world sequential data tasks.
#
# - Build, train, and evaluate Transformer models.

# %% [markdown]
# ## Step-by-Step Instructions:
#
# ### Step 1: Import necessary libraries
#
# Before you start, you need to import the required libraries: TensorFlow and Keras. Keras is included within TensorFlow as `tensorflow.keras.`

# %%
# %pip install tensorflow pyarrow 
# %pip install pandas  
# %pip install scikit-learn 
# %pip install matplotlib 
# %pip install requests
# Out:
# Requirement already satisfied: tensorflow in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (2.19.0)Note: you may need to restart the kernel to use updated packages.
#
# Collecting pyarrow
#   Downloading pyarrow-19.0.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading pyarrow-19.0.1-cp310-cp310-win_amd64.whl (25.3 MB)
#    ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/25.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/25.3 MB ? eta -:--:--
#     --------------------------------------- 0.5/25.3 MB 762.0 kB/s eta 0:00:33
#     --------------------------------------- 0.5/25.3 MB 762.0 kB/s eta 0:00:33
#    - -------------------------------------- 0.8/25.3 MB 780.2 kB/s eta 0:00:32
#    - -------------------------------------- 1.0/25.3 MB 838.4 kB/s eta 0:00:29
#    -- ------------------------------------- 1.3/25.3 MB 860.2 kB/s eta 0:00:28
#    -- ------------------------------------- 1.3/25.3 MB 860.2 kB/s eta 0:00:28
#    -- ------------------------------------- 1.6/25.3 MB 856.1 kB/s eta 0:00:28
#    -- ------------------------------------- 1.6/25.3 MB 856.1 kB/s eta 0:00:28
#    -- ------------------------------------- 1.8/25.3 MB 786.4 kB/s eta 0:00:30
#    -- ------------------------------------- 1.8/25.3 MB 786.4 kB/s eta 0:00:30
#    --- ------------------------------------ 2.1/25.3 MB 752.7 kB/s eta 0:00:31
#    --- ------------------------------------ 2.1/25.3 MB 752.7 kB/s eta 0:00:31
#    --- ------------------------------------ 2.4/25.3 MB 741.6 kB/s eta 0:00:31
#    --- ------------------------------------ 2.4/25.3 MB 741.6 kB/s eta 0:00:31
#    ---- ----------------------------------- 2.6/25.3 MB 712.1 kB/s eta 0:00:32
#    ---- ----------------------------------- 2.6/25.3 MB 712.1 kB/s eta 0:00:32
#    ---- ----------------------------------- 2.9/25.3 MB 713.9 kB/s eta 0:00:32
#    ---- ----------------------------------- 2.9/25.3 MB 713.9 kB/s eta 0:00:32
#    ---- ----------------------------------- 3.1/25.3 MB 693.8 kB/s eta 0:00:32
#    ---- ----------------------------------- 3.1/25.3 MB 693.8 kB/s eta 0:00:32
#    ----- ---------------------------------- 3.4/25.3 MB 689.4 kB/s eta 0:00:32
#    ----- ---------------------------------- 3.7/25.3 MB 699.0 kB/s eta 0:00:31
#    ----- ---------------------------------- 3.7/25.3 MB 699.0 kB/s eta 0:00:31
#    ------ --------------------------------- 3.9/25.3 MB 703.2 kB/s eta 0:00:31
#    ------ --------------------------------- 3.9/25.3 MB 703.2 kB/s eta 0:00:31
#    ------ --------------------------------- 4.2/25.3 MB 702.9 kB/s eta 0:00:30
#    ------ --------------------------------- 4.2/25.3 MB 702.9 kB/s eta 0:00:30
#    ------- -------------------------------- 4.5/25.3 MB 702.7 kB/s eta 0:00:30
#    ------- -------------------------------- 4.7/25.3 MB 702.5 kB/s eta 0:00:30
#    ------- -------------------------------- 4.7/25.3 MB 702.5 kB/s eta 0:00:30
#    ------- -------------------------------- 4.7/25.3 MB 702.5 kB/s eta 0:00:30
#    ------- -------------------------------- 5.0/25.3 MB 691.1 kB/s eta 0:00:30
#    ------- -------------------------------- 5.0/25.3 MB 691.1 kB/s eta 0:00:30
kB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 258.5 kB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 258.5 kB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 260.2 kB/s eta 0:00:00
# Using cached contourpy-1.3.1-cp310-cp310-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp310-cp310-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 356.7 kB/s eta 0:00:05
#    --------- ------------------------------ 0.5/2.2 MB 356.7 kB/s eta 0:00:05
#    --------- ------------------------------ 0.5/2.2 MB 356.7 kB/s eta 0:00:05
#    -------------- ------------------------- 0.8/2.2 MB 372.6 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.2 MB 372.6 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.2 MB 372.6 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.2 MB 384.2 kB/s eta 0:00:03
#    ------------------- -------------------- 1.0/2.2 MB 384.2 kB/s eta 0:00:03
#    ------------------- -------------------- 1.0/2.2 MB 384.2 kB/s eta 0:00:03
#    ------------------- -------------------- 1.0/2.2 MB 384.2 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.3/2.2 MB 374.9 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.3/2.2 MB 374.9 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.3/2.2 MB 374.9 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 379.6 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.6/2.2 MB 379.6 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.6/2.2 MB 379.6 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 384.2 kB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 384.2 kB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 384.2 kB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 381.3 kB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 381.3 kB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 374.7 kB/s eta 0:00:00
# Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Using cached pillow-11.1.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.1.0 pyparsing-3.2.1
# Requirement already satisfied: requests in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf 
import requests
from sklearn.preprocessing import MinMaxScaler 
from tensorflow.keras.layers import Layer, Dense, LayerNormalization, Dropout

# %% [markdown]
# ####  Setup the Environment to generate synthetic stock price data

# %%
import numpy as np
import pandas as pd
from IPython.display import display

# Create a synthetic stock price dataset
np.random.seed(42)
data_length = 2000  # Adjust data length as needed
trend = np.linspace(100, 200, data_length)
noise = np.random.normal(0, 2, data_length)
synthetic_data = trend + noise

# Create a DataFrame and save as 'stock_prices.csv'
data = pd.DataFrame(synthetic_data, columns=['Close'])
data.to_csv('stock_prices.csv', index=False)
print("Synthetic stock_prices.csv created and loaded.")
display(data)
# Out:
# Synthetic stock_prices.csv created and loaded.
#            Close
# 0     100.993428
# 1      99.773496
# 2     101.395427
# 3     103.196135
# 4      99.731793
# ...          ...
# 1995  201.940200
# 1996  199.796882
# 1997  198.136201
# 1998  199.623841
# 1999  198.510195
#
# [2000 rows x 1 columns]

# %%
# Load the dataset 
data = pd.read_csv('stock_prices.csv') 
data = data[['Close']].values 

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# Prepare the data for training
def create_dataset(data, time_step=1):
    X, Y = [], []

    for i in range(len(data)-time_step-1):
        a = data[i:(i+time_step), 0]
        X.append(a)
        Y.append(data[i + time_step, 0])
    return np.array(X), np.array(Y)

time_step = 100
X, Y = create_dataset(data, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

print("Shape of X:", X.shape) 
print("Shape of Y:", Y.shape)
# Out:
# Shape of X: (1899, 100, 1)
# Shape of Y: (1899,)

# %% [markdown]
# In the above code:
#
# `tensorflow` is the main library for machine learning in Python.
#
# `stock_prices.csv` is the data set that is loaded.
#
# `MinMaxScaler` method is used to normalize the data.
#
# `create_dataset`method is used to prepare the data for training.

# %% [markdown]
# ### Step 2: Implement Multi-Head Self-Attention
#
# Define the Multi-Head Self-Attention mechanism.

# %%
class MultiHeadSelfAttention(Layer): 

    def __init__(self, embed_dim, num_heads=8): 
        super(MultiHeadSelfAttention, self).__init__() 
        # This layer implements multi-head attention, which allows the model to focus on different parts of the input sequence simultaneously
        self.embed_dim = embed_dim 
        self.num_heads = num_heads 
        self.projection_dim = embed_dim // num_heads 
        self.query_dense = Dense(embed_dim) 
        self.key_dense = Dense(embed_dim) 
        self.value_dense = Dense(embed_dim) 
        self.combine_heads = Dense(embed_dim) 

    def attention(self, query, key, value): 
        score = tf.matmul(query, key, transpose_b=True) 
        dim_key = tf.cast(tf.shape(key)[-1], tf.float32) 
        scaled_score = score / tf.math.sqrt(dim_key) 
        weights = tf.nn.softmax(scaled_score, axis=-1) 
        output = tf.matmul(weights, value) 
        return output, weights 

    def split_heads(self, x, batch_size): 
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim)) 
        return tf.transpose(x, perm=[0, 2, 1, 3]) 

    def call(self, inputs): 
        batch_size = tf.shape(inputs)[0] 
        query = self.query_dense(inputs) 
        key = self.key_dense(inputs) 
        value = self.value_dense(inputs) 
        query = self.split_heads(query, batch_size) 
        key = self.split_heads(key, batch_size) 
        value = self.split_heads(value, batch_size) 
        attention, _ = self.attention(query, key, value) 
        attention = tf.transpose(attention, perm=[0, 2, 1, 3]) 
        concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim)) 
        output = self.combine_heads(concat_attention) 
        return output

# %% [markdown]
# In the above code:
#
# - The MultiHeadSelfAttention layer implements the multi-head self-attention mechanism, which allows the model to focus on different parts of the input sequence simultaneously.
#
# - The attention parameter computes the attention scores and weighted sum of the values.
#
# - The split_heads parameter splits the input into multiple heads for parallel attention computation.
#
# - The call method applies the self-attention mechanism and combines the heads.

# %% [markdown]
# ### Step 3: Implement Transformer block
#
# Define the Transformer block.

# %%
class TransformerBlock(Layer): 

    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1): 
        super(TransformerBlock, self).__init__() 
        self.att = MultiHeadSelfAttention(embed_dim, num_heads) 
        self.ffn = tf.keras.Sequential([ 
            Dense(ff_dim, activation="relu"), 
            Dense(embed_dim), 
        ]) 

        self.layernorm1 = LayerNormalization(epsilon=1e-6) 
        self.layernorm2 = LayerNormalization(epsilon=1e-6) 
        self.dropout1 = Dropout(rate) 
        self.dropout2 = Dropout(rate) 


    def call(self, inputs, training): 
        attn_output = self.att(inputs) 
        attn_output = self.dropout1(attn_output, training=training) 
        out1 = self.layernorm1(inputs + attn_output) 
        ffn_output = self.ffn(out1) 
        ffn_output = self.dropout2(ffn_output, training=training) 
        return self.layernorm2(out1 + ffn_output)

# %% [markdown]
# In the above code:
#
# - The TransformerBlock layer combines multi-head self-attention with a feed-forward neural network and normalization layers.
#
# - Dropout is used to prevent overfitting.
#
# - The call method applies the self-attention, followed by the feedforward network with residual connections and layer normalization.

# %% [markdown]
# ### Step 4: Implement Encoder Layer
#
# Define the Encoder layer.

# %%
class EncoderLayer(Layer): 

    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1): 
        super(EncoderLayer, self).__init__() 
        self.att = MultiHeadSelfAttention(embed_dim, num_heads) 
        self.ffn = tf.keras.Sequential([ 
            Dense(ff_dim, activation="relu"), 
            Dense(embed_dim), 
        ]) 

        self.layernorm1 = LayerNormalization(epsilon=1e-6) 
        self.layernorm2 = LayerNormalization(epsilon=1e-6) 
        self.dropout1 = Dropout(rate) 
        self.dropout2 = Dropout(rate) 

 

    def call(self, inputs, training): 
        attn_output = self.att(inputs) 
        attn_output = self.dropout1(attn_output, training=training) 
        out1 = self.layernorm1(inputs + attn_output) 
        ffn_output = self.ffn(out1) 
        ffn_output = self.dropout2(ffn_output, training=training) 
        return self.layernorm2(out1 + ffn_output)

# %% [markdown]
# In the above code:
#
# - The EncoderLayer is similar to the TransformerBlock but is a reusable layer in the Transformer architecture.
#
# - It consists of a MultiHeadSelfAttention mechanism followed by a feedforward neural network.
#
# - Both sub-layers have residual connections around them, and layer normalization is applied to the output of each sub-layer.
#
# - The call method applies the self-attention, followed by the feedforward network, with residual connections and layer normalization.

# %% [markdown]
# ### Step 5: Implement Transformer encoder
#
# Define the Transformer Encoder.

# %%
import tensorflow as tf 
from tensorflow.keras.layers import Layer, Dense, LayerNormalization, Dropout 

class MultiHeadSelfAttention(Layer): 
    def __init__(self, embed_dim, num_heads=8): 
        super(MultiHeadSelfAttention, self).__init__() 
        self.embed_dim = embed_dim 
        self.num_heads = num_heads 
        self.projection_dim = embed_dim // num_heads 
        self.query_dense = Dense(embed_dim) 
        self.key_dense = Dense(embed_dim) 
        self.value_dense = Dense(embed_dim) 
        self.combine_heads = Dense(embed_dim) 
 

    def attention(self, query, key, value): 
        score = tf.matmul(query, key, transpose_b=True) 
        dim_key = tf.cast(tf.shape(key)[-1], tf.float32) 
        scaled_score = score / tf.math.sqrt(dim_key) 
        weights = tf.nn.softmax(scaled_score, axis=-1) 
        output = tf.matmul(weights, value) 
        return output, weights 


    def split_heads(self, x, batch_size): 
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim)) 
        return tf.transpose(x, perm=[0, 2, 1, 3]) 


    def call(self, inputs): 
        batch_size = tf.shape(inputs)[0] 
        query = self.query_dense(inputs) 
        key = self.key_dense(inputs) 
        value = self.value_dense(inputs) 
        query = self.split_heads(query, batch_size) 
        key = self.split_heads(key, batch_size) 
        value = self.split_heads(value, batch_size) 
        attention, _ = self.attention(query, key, value) 
        attention = tf.transpose(attention, perm=[0, 2, 1, 3]) 
        concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim)) 
        output = self.combine_heads(concat_attention) 
        return output 

class TransformerBlock(Layer): 
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1): 
        super(TransformerBlock, self).__init__() 
        self.att = MultiHeadSelfAttention(embed_dim, num_heads) 
        self.ffn = tf.keras.Sequential([ 
            Dense(ff_dim, activation="relu"), 
            Dense(embed_dim), 
        ]) 

        self.layernorm1 = LayerNormalization(epsilon=1e-6) 
        self.layernorm2 = LayerNormalization(epsilon=1e-6) 
        self.dropout1 = Dropout(rate) 
        self.dropout2 = Dropout(rate) 
 

    def call(self, inputs, training): 
        attn_output = self.att(inputs) 
        attn_output = self.dropout1(attn_output, training=training) 
        out1 = self.layernorm1(inputs + attn_output) 
        ffn_output = self.ffn(out1) 
        ffn_output = self.dropout2(ffn_output, training=training) 
        return self.layernorm2(out1 + ffn_output) 

class TransformerEncoder(Layer): 
    def __init__(self, num_layers, embed_dim, num_heads, ff_dim, rate=0.1): 
        super(TransformerEncoder, self).__init__() 
        self.num_layers = num_layers 
        self.embed_dim = embed_dim 
        self.enc_layers = [TransformerBlock(embed_dim, num_heads, ff_dim, rate) for _ in range(num_layers)] 
        self.dropout = Dropout(rate) 

    def call(self, inputs, training=False): 
        x = inputs 
        for i in range(self.num_layers): 
            x = self.enc_layers[i](x, training=training) 
        return x 

# Example usage 
embed_dim = 128 
num_heads = 8 
ff_dim = 512 
num_layers = 4 

transformer_encoder = TransformerEncoder(num_layers, embed_dim, num_heads, ff_dim) 
inputs = tf.random.uniform((1, 100, embed_dim)) 
outputs = transformer_encoder(inputs, training=False)  # Use keyword argument for 'training' 
print(outputs.shape)  # Should print (1, 100, 128)
# Out:
# (1, 100, 128)

# %% [markdown]
# In the above code:
#
# The TransformerEncoder is composed of multiple TransformerBlock layers, implementing the encoding part of the Transformer architecture.

# %% [markdown]
# ### Step 6: Build and Compile the Transformer model
#
# Integrate the Transformer Encoder into a complete model for sequential data.

# %%
# Define the necessary parameters 

embed_dim = 128 
num_heads = 8 
ff_dim = 512 
num_layers = 4 

# Define the Transformer Encoder 
transformer_encoder = TransformerEncoder(num_layers, embed_dim, num_heads, ff_dim) 

# Build the model 
input_shape = (X.shape[1], X.shape[2]) 
inputs = tf.keras.Input(shape=input_shape) 

# Project the inputs to the embed_dim 
x = tf.keras.layers.Dense(embed_dim)(inputs) 
encoder_outputs = transformer_encoder(x) 
flatten = tf.keras.layers.Flatten()(encoder_outputs) 
outputs = tf.keras.layers.Dense(1)(flatten) 
model = tf.keras.Model(inputs, outputs) 

# Compile the model 
model.compile(optimizer='adam', loss='mse') 

# Summary of the model 
model.summary()
# Out:
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_17 (InputLayer)     │ (None, 100, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_123 (Dense)               │ (None, 100, 128)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_encoder_4           │ (None, 100, 128)       │       793,088 │
# │ (TransformerEncoder)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_124 (Dense)               │ (None, 1)              │        12,801 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 806,145 (3.08 MB)
#  Trainable params: 806,145 (3.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# In the above code:
#
# - The Transformer Encoder model defines the necessary parameters, flattens the output, and ends with a dense layer to produce the final output.
#
# - The model is then compiled with the Adam optimizer and mean squared error loss.
#
# This table represents the **architecture of a deep learning model** in **Keras/TensorFlow**. Let's see together what each line means:
#
# ### **Model structure**
# | **Layer (type)** | **Output Shape** | **Param #** | **Description** |
# |---------------------------------|-------------------|------------|----------------|
# | **input_layer_4 (InputLayer)** | (None, 100, 1) | 0 | **Input layer:** accepts sequences of length **100** with **1 feature per timestep**. |
# | **dense_48 (Dense)** | (None, 100, 128) | 256 | **Dense layer:** Each timestep (100) is transformed into a vector of **128 units**. |
# | **transformer_encoder_1 (TransformerEncoder)** | (None, 100, 128) | 793,088 | **Transformer Encoder:** Models complex dependencies in sequential data. |
# | **flatten (Flatten)** | (None, 12800) | 0 | **Flatten:** Flattens the data into a 1D vector for final classification. |
# | **dense_49 (Dense)** | (None, 1) | 12,801 | **Last Layer:** Maps the final vector into a single output (e.g. regression or binary classification). |
#
# ---
#
# ### **Detailed Analysis**
# 1. **Input Layer (input_layer_4)**
# - Accepts data in the form **(None, 100, 1)**, i.e.:
# - **None** → dynamic batch size.
# - **100** → length of the sequence.
# - **1** → 1 feature per timestep.
#
# 2. **Dense Layer (dense_48)**
# - **Transforms each timestep** from 1 dimension to 128 dimensions.
# - **256 parameters** → why? Formula:
#
# $$text{Parameters} = (\text{Input} \times \text{Output}) + \text{Bias} = (1 \times 128) + 128 = 256$$
#
# 3. **Transformer Encoder Layer (transformer_encoder_1)**
# - Keeps the same dimension **(100, 128)**.
# - Has **793,088 parameters** (probably a **multi-head self-attention** and feedforward model).
#
# 4. **Flatten Layer**
# - Converts the tensor from **(100, 128)** to **(12800,)** (100 × 128).
#
# 5. **Final Dense Layer (dense_49)**
# - **Scalar Output (1 value)** → can be for **regression** or **binary classification**.
#
# $$text{Parameters} = (\text{Input} \times \text{Output}) + \text{Bias} = (12800 \times 1) + 1 = 12,801$$

# %% [markdown]
# ### Step 7: Train the Transformer model
#
# Train the model on the prepared dataset.

# %%
# Train the model
model.fit(X, Y, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 33s 233ms/step - loss: 12.2545
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 254ms/step - loss: 0.2510
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - loss: 0.1622
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 260ms/step - loss: 0.1408
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 263ms/step - loss: 0.2687
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 259ms/step - loss: 0.1689
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 259ms/step - loss: 0.1585
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 217ms/step - loss: 0.1039
# Epoch 9/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 217ms/step - loss: 0.1589
# Epoch 10/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 209ms/step - loss: 0.1013
# Epoch 11/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - loss: 0.1081
# Epoch 12/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 212ms/step - loss: 0.1086
# Epoch 13/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 199ms/step - loss: 0.1068
# Epoch 14/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 199ms/step - loss: 0.1075
# Epoch 15/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - loss: 0.0554
# Epoch 16/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 226ms/step - loss: 0.0521
# Epoch 17/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 268ms/step - loss: 0.0518
# Epoch 18/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 266ms/step - loss: 0.0437
# Epoch 19/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 265ms/step - loss: 0.0327
# Epoch 20/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 264ms/step - loss: 0.0480

# %% [markdown]
# In the above code:
#
# The model is trained on the normalized stock price data for 20 epochs with a batch size of 32.

# %% [markdown]
# ### Step 8: Evaluate and Make Predictions
#
# Evaluate the model's performance and make predictions on the dataset.

# %%
# Make predictions 
predictions = model.predict(X) 
predictions = scaler.inverse_transform(predictions) 
 

# Plot the predictions 
import matplotlib.pyplot as plt 

plt.plot(data, label='True Data') 
plt.plot(np.arange(time_step, time_step + len(predictions)), predictions, label='Predictions') 
plt.xlabel('Time') 
plt.ylabel('Stock Price') 
plt.legend() 
plt.show()
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step

# %% [markdown]
# In the above code:
#
# - The model's predictions are transformed back to the original scale using the inverse transform of the scaler.
#
# - The true data and predictions are plotted to visualize the model's performance.

# %% [markdown]
# ## Practice Exercises:
#
#  ### Exercise 1: Add dropout to the Transformer model
#
#  **Objective: Understand how to add dropout layers to the Transformer model to prevent overfitting.**
#
#  Instructions:
#
# - Add a dropout layer after the Flatten layer in the model.
#
# - Set the dropout rate to 0.5.

# %%
## Write your code here.
from tensorflow.keras.layers import Layer, Dense, LayerNormalization, Dropout

flatten = tf.keras.layers.Flatten()(encoder_outputs) 
dropout = Dropout(0.5)(flatten) 
outputs = tf.keras.layers.Dense(1)(dropout) 

model = tf.keras.Model(inputs, outputs) 

model.compile(optimizer='adam', loss='mse') 
model.fit(X, Y, epochs=20, batch_size=32) 

# Evaluate the model 

loss = model.evaluate(X, Y) 

print(f'Test loss: {loss}')
# Out:
# Epoch 1/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 37s 269ms/step - loss: 13.1540
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 268ms/step - loss: 1.9841
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 268ms/step - loss: 1.6376
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 209ms/step - loss: 0.9692
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - loss: 0.5255
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 203ms/step - loss: 0.1912
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 262ms/step - loss: 0.1393
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 17s 274ms/step - loss: 0.0604
# Epoch 9/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 291ms/step - loss: 0.0526
# Epoch 10/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.0378
# Epoch 11/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 230ms/step - loss: 0.0488
# Epoch 12/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 236ms/step - loss: 0.0272
# Epoch 13/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 215ms/step - loss: 0.0249
# Epoch 14/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - loss: 0.0236
# Epoch 15/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 215ms/step - loss: 0.0198
# Epoch 16/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 204ms/step - loss: 0.0192
# Epoch 17/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 194ms/step - loss: 0.0246
# Epoch 18/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - loss: 0.0302
# Epoch 19/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 195ms/step - loss: 0.0169
# Epoch 20/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - loss: 0.0183
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 6.9112e-04
# Test loss: 0.0014807968400418758

# %% [markdown]
# ### Exercise 2: Experiment with different batch sizes
#
# **Objective: Observe the impact of different batch sizes on model performance.**
#
#  Instructions:
#
# - Train the model with a batch size of 16.
#
# - Train the model with a batch size of 64.
#
# - Compare the training time and performance.

# %%
## Write your code here.
# model.fit(X, Y, epochs=20, batch_size=16) 
model.fit(X, Y, epochs=20, batch_size=64)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 12s 412ms/step - loss: 0.0085
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 419ms/step - loss: 0.0056
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 12s 414ms/step - loss: 0.0043
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 12s 401ms/step - loss: 0.0043
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 455ms/step - loss: 0.0043
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 456ms/step - loss: 0.0043
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 444ms/step - loss: 0.0048
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 439ms/step - loss: 0.0047
# Epoch 9/20
# 12/30 ━━━━━━━━━━━━━━━━━━━━ 8s 456ms/step - loss: 0.0040

# %% [markdown]
# <details><summary>Click here to view the solution.</summary>
#
# ```
# # Train the model with batch size 16
# model.fit(X, Y, epochs=20, batch_size=16)
#
# # Evaluate the model
# loss = model.evaluate(X, Y)
# print(f'Test loss with batch size 16: {loss}')
#
# # Train the model with batch size 64
# model.fit(X, Y, epochs=20, batch_size=64)
#
# # Evaluate the model
# loss = model.evaluate(X, Y)
# print(f'Test loss with batch size 64: {loss}')
#
# ```
# </details>

# %% [markdown]
# ### Exercise 3: Use a different activation function
#
#  **Objective: Understand how different activation functions impact the model performance.**
#
#  Instructions:
#
# - Change the activation function of the Dense layer to `tanh`.
#
# - Train and evaluate the model.

# %%
## Write your code here.
class TransformerBlock(Layer): 
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1): 
        super(TransformerBlock, self).__init__() 
        self.att = MultiHeadSelfAttention(embed_dim, num_heads) 
        self.ffn = tf.keras.Sequential([ 
            Dense(ff_dim, activation="tanh"), # Added activation function layer tanh
            Dense(embed_dim), 
        ])

# %% [markdown]
# <details><summary>Click here to view the solution.</summary>
#
# ```
# # Change the activation function of the Dense layer to tanh
# outputs = tf.keras.layers.Dense(1, activation='tanh')(flatten)
#
# # Build the model
# model = tf.keras.Model(inputs, outputs)
#
# # Compile the model
# model.compile(optimizer='adam', loss='mse')
#
# # Train the model
# model.fit(X, Y, epochs=20, batch_size=32)
#
# # Evaluate the model
# loss = model.evaluate(X, Y)
# print(f'Test loss with tanh activation: {loss}')
#
# ```
# </details>

# %% [markdown]
# ## Conclusion
# Congratulations on completing this lab! In this lab, you have built an advanced Transformer model using Keras and applied it to a time series forecasting task. You have learned how to define and implement multi-head self-attention, Transformer blocks, encoder layers, and integrate them into a complete Transformer model. By experimenting with different configurations and training the model, you can further improve its performance and apply it to various sequential data tasks.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
