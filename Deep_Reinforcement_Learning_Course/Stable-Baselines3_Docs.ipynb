# %% [markdown]
# # **[Stable-Baselines3 (SB3)](https://stable-baselines3.readthedocs.io/en/master/)**
# ### **What is Stable-Baselines3?**
# Stable-Baselines3 (SB3) is an **open-source PyTorch-based library** that reliably implements **Reinforcement Learning (RL) algorithms**.

# %% [markdown]
# ## **Installation**
#
# ### **Stable version**
# To install the stable version with all optional packages (TensorBoard, OpenCV, ale-py for Atari)

# %%
# %pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (2.5.0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: cloudpickle in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (3.10.1)
# Collecting opencv-python (from stable-baselines3[extra])
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting pygame (from stable-baselines3[extra])
#   Downloading pygame-2.6.1-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (2.19.0)
# Requirement already satisfied: psutil in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (7.0.0)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (13.9.4)
# Collecting ale-py>=0.9.0 (from stable-baselines3[extra])
#   Downloading ale_py-0.10.2-cp310-cp310-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: pillow in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from stable-baselines3[extra]) (11.1.0)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from ale-py>=0.9.0->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (5.29.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.8.2)
# Requirement already satisfied: six>1.9 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.18.0)
# Requirement already satisfied: networkx in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from pandas->stable-baselines3[extra]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from pandas->stable-baselines3[extra]) (2025.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from rich->stable-baselines3[extra]) (2.19.1)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Downloading ale_py-0.10.2-cp310-cp310-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.5 MB 1.5 MB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.5 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.5 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 1.4 MB/s eta 0:00:00
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Downloading pygame-2.6.1-cp310-cp310-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.6 MB 1.3 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/10.6 MB 1.5 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/10.6 MB 1.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/10.6 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/10.6 MB 1.4 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/10.6 MB 1.3 MB/s eta 0:00:07
#    ------- -------------------------------- 2.1/10.6 MB 1.3 MB/s eta 0:00:07
#    -------- ------------------------------- 2.4/10.6 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.6/10.6 MB 1.3 MB/s eta 0:00:07
#    --------- ------------------------------ 2.6/10.6 MB 1.3 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.1/10.6 MB 1.2 MB/s eta 0:00:07
#    ------------ --------------------------- 3.4/10.6 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.7/10.6 MB 1.2 MB/s eta 0:00:06
#    -------------- ------------------------- 3.9/10.6 MB 1.3 MB/s eta 0:00:06
#    --------------- ------------------------ 4.2/10.6 MB 1.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.5/10.6 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 5.0/10.6 MB 1.3 MB/s eta 0:00:05
#    --------------------- ------------------ 5.8/10.6 MB 1.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.3/10.6 MB 1.5 MB/s eta 0:00:03
#    -------------------------- ------------- 7.1/10.6 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.9/10.6 MB 1.7 MB/s eta 0:00:02
#    ------------------------------ --------- 8.1/10.6 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 8.9/10.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.6 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.6 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 10.2/10.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 1.8 MB/s eta 0:00:00
# Installing collected packages: pygame, opencv-python, ale-py
# Successfully installed ale-py-0.10.2 opencv-python-4.11.0.86 pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# If you **don't need the extra dependencies**, install only the base library:

# %%
# %pip install stable-baselines3

# %% [markdown]
# ## Stable-Baselines3 (SB3) **Quick Start Guide**
# * **Key Concepts**
# SB3 uses **vectorized environments (VecEnv)**, which allows **multiple instances of an environment to be run simultaneously**, improving training efficiency compared to a single Gym environment.
# The library follows a similar syntax to scikit-learn for training and using Reinforcement Learning algorithms.
#
#
# **Example: Train A2C on CartPole**
# The following code shows how to train and test an A2C agent on CartPole-v1:
#
# **Steps**:
# 1. Import the necessary **libraries**.
# 2. Create the **Gymnasium environment**.
# 3. Initialize the **A2C model with MlpPolicy**.
# 4. **Train the model** for 10_000 steps.
# 5. **Test the model** for 1000 steps.

# %%
import gymnasium as gym
from stable_baselines3 import A2C

# %%
# Create the **Gymnasium environment**
env = gym.make("CartPole-v1", render_mode="rgb_array")

# %%
# Initialize the **A2C model with MlpPolicy**.
model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.1     |
# |    ep_rew_mean        | 26.1     |
# | time/                 |          |
# |    fps                | 478      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.671   |
# |    explained_variance | -0.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.76     |
# |    value_loss         | 10.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 32.8     |
# |    ep_rew_mean        | 32.8     |
# | time/                 |          |
# |    fps                | 490      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.598   |
# |    explained_variance | 0.00621  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 2.01     |
# |    value_loss         | 7.37     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.6     |
# |    ep_rew_mean        | 37.6     |
# | time/                 |          |
# |    fps                | 493      |
# |    iterations         | 300      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | -0.013   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.52     |
# |    value_loss         | 6.63     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.4     |
# |    ep_rew_mean        | 43.4     |
# | time/                 |          |
# |    fps                | 486      |
# |    iterations         | 400      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.575   |
# |    explained_variance | -0.00602 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -11.2    |
# |    value_loss         | 540      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.6     |
# |    ep_rew_mean        | 46.6     |
# | time/                 |          |
# |    fps                | 493      |
# |    iterations         | 500      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.417   |
# |    explained_variance | 0.00689  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 2.1      |
# |    value_loss         | 5.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50.3     |
# |    ep_rew_mean        | 50.3     |
# | time/                 |          |
# |    fps                | 486      |
# |    iterations         | 600      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.596   |
# |    explained_variance | -0.00124 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.964    |
# |    value_loss         | 4.61     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.4     |
# |    ep_rew_mean        | 53.4     |
# | time/                 |          |
# |    fps                | 490      |
# |    iterations         | 700      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.602   |
# |    explained_variance | 0.0104   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.681    |
# |    value_loss         | 4        |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 56.2     |
# |    ep_rew_mean        | 56.2     |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 800      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.542   |
# |    explained_variance | 0.000689 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.903    |
# |    value_loss         | 3.53     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 61.4     |
# |    ep_rew_mean        | 61.4     |
# | time/                 |          |
# |    fps                | 495      |
# |    iterations         | 900      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.547   |
# |    explained_variance | 0.000171 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.728    |
# |    value_loss         | 3.01     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 64.6     |
# |    ep_rew_mean        | 64.6     |
# | time/                 |          |
# |    fps                | 497      |
# |    iterations         | 1000     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.562   |
# |    explained_variance | 0.001    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.491    |
# |    value_loss         | 2.54     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 71.3      |
# |    ep_rew_mean        | 71.3      |
# | time/                 |           |
# |    fps                | 497       |
# |    iterations         | 1100      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.447    |
# |    explained_variance | -3.81e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 0.236     |
# |    value_loss         | 2.11      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 75.6     |
# |    ep_rew_mean        | 75.6     |
# | time/                 |          |
# |    fps                | 461      |
# |    iterations         | 1200     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.38    |
# |    explained_variance | 8.32e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.222    |
# |    value_loss         | 1.71     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 79.8      |
# |    ep_rew_mean        | 79.8      |
# | time/                 |           |
# |    fps                | 434       |
# |    iterations         | 1300      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.365    |
# |    explained_variance | -7.88e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.346     |
# |    value_loss         | 1.35      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 84.5      |
# |    ep_rew_mean        | 84.5      |
# | time/                 |           |
# |    fps                | 414       |
# |    iterations         | 1400      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.379    |
# |    explained_variance | -2.01e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 0.265     |
# |    value_loss         | 1.05      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.4     |
# |    ep_rew_mean        | 87.4     |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 1500     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.358   |
# |    explained_variance | 2.31e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.499    |
# |    value_loss         | 0.777    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 89.7      |
# |    ep_rew_mean        | 89.7      |
# | time/                 |           |
# |    fps                | 393       |
# |    iterations         | 1600      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.45     |
# |    explained_variance | -2.75e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 0.312     |
# |    value_loss         | 0.544     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93.2      |
# |    ep_rew_mean        | 93.2      |
# | time/                 |           |
# |    fps                | 397       |
# |    iterations         | 1700      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.454    |
# |    explained_variance | -6.01e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.223     |
# |    value_loss         | 0.354     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 98.5      |
# |    ep_rew_mean        | 98.5      |
# | time/                 |           |
# |    fps                | 401       |
# |    iterations         | 1800      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.369    |
# |    explained_variance | -6.75e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 0.147     |
# |    value_loss         | 0.205     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 103       |
# |    ep_rew_mean        | 103       |
# | time/                 |           |
# |    fps                | 407       |
# |    iterations         | 1900      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.385    |
# |    explained_variance | -1.67e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.0975    |
# |    value_loss         | 0.0965    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 103       |
# |    ep_rew_mean        | 103       |
# | time/                 |           |
# |    fps                | 411       |
# |    iterations         | 2000      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.352    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.0575    |
# |    value_loss         | 0.0299    |
# -------------------------------------

# %%
# Getting the vectorized environment
vec_env = model.get_env()
obs = vec_env.reset()

# %%
# Model testing
for i in range(1000):
 action, _state = model.predict(obs, deterministic=True)
 obs, reward, done, info = vec_env.step(action)
 vec_env.render("human") # Show the environment

# %% [markdown]
# **What Happens During Training?**
# - The **agent observes the current state** of the environment (obs).
# - **Predicts an action** based on the trained **policy**.
# - **Executes the action** and **receives a reward**.
# - **Updates the policy** based on accumulated experiences.
# - **Repeats the process** until the defined number of steps (total_timesteps) is reached.
